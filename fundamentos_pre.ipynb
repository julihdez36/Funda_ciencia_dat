# %%
# Vamos a empeza importando modulos utiles para la ciencia de datos

import numpy as np # Array
import pandas as pd # Trabajo don data frames y pandas series [vectores]
import matplotlib.pyplot as plt # Librería gráfica
import seaborn as sns

# %%
penguins = sns.load_dataset('penguins')
stock = sns.load_dataset('dowjones')

# %% [markdown]
# ### Deficiniones útiles para iniciar a trabajar con datos
#
# ## Clasificación del conjunto de datos (dataset)
#
# 1. Cross-sectional [corte transversal]: tengo variables sobre un conjunto de registros en un corte específico del tiempo. **IDD: Independientes e identicamente distribuidos**
# 2. Time series [series temporales]: son registros indexados por el tiempo.
# 3. Longitudinales:
#
# **Variable:** Una característica observable. Cuando la carcateristica no se observa hablamos de *variables latentes* y generalmente se tratantan con *proxys*.
#
# - **Cuantitativas:** escala numérica de medición
#     - Continuas: medición [Dominio reales]
#     - Discretas: Conteo [Dominio enteros]
# - **Cualitativas:** escala categóriga de medición.
#     - Ordinales: orden implícito
#     - Nominales: sin orden implícito
#
#
# ### Análsis exploratorio de los datos [EDA]
#
# 1. Métodos tabulares
# 2. Métodos numéricos
# 3. Métodos gráficos
#
# ![image.png](attachment:image.png)

# %%
penguins.sample(2)
# Out:
#     species  island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 341  Gentoo  Biscoe            50.4           15.7              222.0
# 222  Gentoo  Biscoe            48.7           14.1              210.0
#
#      body_mass_g     sex
# 341       5750.0    Male
# 222       4450.0  Female

# %%
type(penguins)

penguins.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 344 entries, 0 to 343
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   species            344 non-null    object
#  1   island             344 non-null    object
#  2   bill_length_mm     342 non-null    float64
#  3   bill_depth_mm      342 non-null    float64
#  4   flipper_length_mm  342 non-null    float64
#  5   body_mass_g        342 non-null    float64
#  6   sex                333 non-null    object
# dtypes: float64(4), object(3)
# memory usage: 18.9+ KB

# %%
# cómo acceder a una columna

penguins.species
penguins[['species', 'sex']].head(2)
# Out:
#   species     sex
# 0  Adelie    Male
# 1  Adelie  Female

# %%
# Cuántas especies de pinguinos están siendo evaluadas
# Tabla de frecuencia

penguins.species.value_counts(dropna= False) #desbalance de clase
# Out:
# species
# Adelie       152
# Gentoo       124
# Chinstrap     68
# Name: count, dtype: int64

# %%
# Composición de sexo

penguins.sex.value_counts(dropna=False, normalize=True) * 100
# Out:
# sex
# Male      48.837209
# Female    47.965116
# NaN        3.197674
# Name: proportion, dtype: float64

# %%
# Tablas de contingencia entre sexo y especie

pd.crosstab(penguins.species, penguins.sex, dropna= False)
# Out:
# sex        Female  Male  NaN
# species
# Adelie         73    73    6
# Chinstrap      34    34    0
# Gentoo         58    61    5

# %%
# Ecuaciones mince: retornos educativos
# contactos

# %%
plt.plot(stock.Date, stock.Price)
plt.grid();
